# %% [markdown]
# <a href="https://colab.research.google.com/github/busybee-123/Pollinator_Cam/blob/main/train_yolo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Mounted at /content/drive
# Cloning into 'yolov5'...
# remote: Enumerating objects: 18370, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (43/43), done.
# remote: Total 18370 (delta 43), reused 24 (delta 24), pack-reused 18303 (from 2)
# Receiving objects: 100% (18370/18370), 17.47 MiB | 24.02 MiB/s, done.
# Resolving deltas: 100% (12485/12485), done.
# /content/yolov5
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.0/41.0 kB 1.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 23.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.1/131.1 kB 15.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.5.0
#     Uninstalling urllib3-2.5.0:
#       Successfully uninstalled urllib3-2.5.0
# ...

# %%
# !bash -c 'PYTHONWARNINGS="ignore" python train.py --weights yolov5s.pt --data "/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/bee_dataset/data.yaml" --freeze 24 --epochs 20'
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout) 3
# wandb: You chose "Don't visualize my results"
# wandb: Using W&B in offline mode.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# ...

# %%
# !cp -r /content/yolov5/runs/train/exp2 '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/bee_dataset/'

# %%
from ultralytics import YOLO

# %% [markdown]
# ### Loading an Object Detection Model (e.g., YOLOv8s)

# %%
# Load a pre-trained YOLOv8s object detection model
model = YOLO("yolo11n.pt")
print(f"Model loaded: {model.task} model with {model.nc} classes.")

# You can also explore different model types like:
# model = YOLO('yolov8n.pt')  # Nano model
# model = YOLO('yolov8m.pt')  # Medium model
# model = YOLO('yolov8l.pt')  # Large model
# model = YOLO('yolov8x.pt')  # Extra large model

# For segmentation tasks:
# model = YOLO('yolov8n-seg.pt')

# For classification tasks:
# model = YOLO('yolov8n-cls.pt')
# Out:
# ...
# Model loaded: detect model with 80 classes.
