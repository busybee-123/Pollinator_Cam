# %% [markdown]
# <a href="https://colab.research.google.com/github/busybee-123/Pollinator_Cam/blob/main/Segment_and_create_composite_images.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Configuration

# %%
# Mount Google Drive to access your files
from google.colab import drive
drive.mount('/content/drive')

# Install Pillow for image processing
# %pip install Pillow

# Clone and install flat-bug if not already present
import sys
import os
if not os.path.exists('flat-bug'):
    # !git clone https://github.com/darsa-group/flat-bug.git
# !bash -c "cd flat-bug && {sys.executable} -m pip install -e ."
# Out:
# Mounted at /content/drive
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Cloning into 'flat-bug'...
# remote: Enumerating objects: 3601, done.
# remote: Counting objects: 100% (403/403), done.
# remote: Compressing objects: 100% (231/231), done.
# remote: Total 3601 (delta 194), reused 183 (delta 166), pack-reused 3198 (from 2)
# Receiving objects: 100% (3601/3601), 46.07 MiB | 18.92 MiB/s, done.
# Resolving deltas: 100% (2046/2046), done.
# Obtaining file:///content/flat-bug
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flat-bug==1.0.0) (2.11.0+cu128)
# Requirement already satisfied: torchvision>=0.17.0 in /usr/local/lib/python3.12/dist-packages (from flat-bug==1.0.0) (0.26.0+cu128)
# Collecting ultralytics<=8.3.124,>=8.2.16 (from flat-bug==1.0.0)
#   Downloading ultralytics-8.3.124-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: shapely>=2.0.2 in /usr/local/lib/python3.12/dist-packages (from flat-bug==1.0.0) (2.1.2)
# Collecting scikit-optimize>=0.10.1 (from flat-bug==1.0.0)
#   Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: scipy>=1.14.1 in /usr/local/lib/python3.12/dist-packages (from flat-bug==1.0.0) (1.16.3)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize>=0.10.1->flat-bug==1.0.0) (1.5.3)
# Collecting pyaml>=16.9 (from scikit-optimize>=0.10.1->flat-bug==1.0.0)
#   Downloading pyaml-26.7.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize>=0.10.1->flat-bug==1.0.0) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize>=0.10.1->flat-bug==1.0.0) (1.6.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.12/dist-packages (from scikit-optimize>=0.10.1->flat-bug==1.0.0) (26.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (3.29.7)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (4.16.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (12.9.7)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2.0->flat-bug==1.0.0) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.2.0->flat-bug==1.0.0) (12.8.90)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision>=0.17.0->flat-bug==1.0.0) (11.3.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (5.0.0.93)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (2.32.4)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (0.13.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0)
#   Downloading ultralytics_thop-2.0.20-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.2.0->flat-bug==1.0.0) (1.5.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1.4->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (2026.6.17)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.0.0->scikit-optimize>=0.10.1->flat-bug==1.0.0) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2.0->flat-bug==1.0.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2.0->flat-bug==1.0.0) (3.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics<=8.3.124,>=8.2.16->flat-bug==1.0.0) (1.17.0)
# Downloading scikit_optimize-0.10.2-py2.py3-none-any.whl (107 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.8/107.8 kB 11.3 MB/s eta 0:00:00
# Downloading ultralytics-8.3.124-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 72.0 MB/s eta 0:00:00
# Downloading pyaml-26.7.0-py3-none-any.whl (27 kB)
# Downloading ultralytics_thop-2.0.20-py3-none-any.whl (28 kB)
# Building wheels for collected packages: flat-bug
#   Building editable for flat-bug (pyproject.toml) ... done
#   Created wheel for flat-bug: filename=flat_bug-1.0.0-0.editable-py3-none-any.whl size=6092 sha256=7a32a88f33532f90ca34acb02cbaf3b1fa4e6ae7ec728d1add1fe3c188c82cda
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fvfjfn9r/wheels/e8/90/6b/ed1a266709b6e34628f1959b80f37c39cc10e3f5534cc5eb73
# Successfully built flat-bug
# Installing collected packages: pyaml, scikit-optimize, ultralytics-thop, ultralytics, flat-bug
# Successfully installed flat-bug-1.0.0 pyaml-26.7.0 scikit-optimize-0.10.2 ultralytics-8.3.124 ultralytics-thop-2.0.20

# %% [markdown]
# ## Prepare new training dataset

# %% [markdown]
# ### Run Flatbug on the entire original dataset to get segmented crops

# %%
# !fb_predict --no-overviews -R -i /content/drive/MyDrive/Colab\ Notebooks/Pollinator\ Camera\ Project/dataset -o /content/drive/MyDrive/Colab\ Notebooks/Pollinator\ Camera\ Project/dataset_flatbug_crops
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Downloading https://anon.erda.au.dk/share_redirect/Bb0CR1FHG6/models/flat_bug_M.pt to flat_bug_M.pt: 49.7MB [00:09, 5.16MB/s]
# YOLOv8m-seg summary (fused): 111 layers, 24,586,035 parameters, 0 gradients, 93.0 GFLOPs
# Processing images: 100% 2760/2760 [18:21<00:00,  2.51image/s, Processing cropped_Yellow_faced_bee__Hylaeus__5939007084__supplementary_preserved.jpg]
# Finishing pending executions.: 100% 1/1 [00:00<00:00, 878.02it/s]

# %% [markdown]
# ### Find how many images Flatbug successfully ran on

# %%
import os

dataset_flatbug_crops_dir = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops'

image_extensions = ('.png', '.jpg', '.jpeg', '.gif', '.bmp')

# Initialize counters for each category
human_category = {'total_folders': 0, '0_images': 0, '1_image': 0, '2_plus_images': 0}
preserved_category = {'total_folders': 0, '0_images': 0, '1_image': 0, '2_plus_images': 0}
other_category = {'total_folders': 0, '0_images': 0, '1_image': 0, '2_plus_images': 0}

# Walk through the dataset_flatbug_crops directory
for root, dirs, files in os.walk(dataset_flatbug_crops_dir):
    # We are interested in immediate subdirectories that contain image files
    # The flatbug output structure creates a subdirectory for each input image
    # where the cropped images are placed.
    if root == dataset_flatbug_crops_dir:
        continue # Skip the root directory itself, only process its immediate subdirectories

    current_folder_image_count = 0
    for file in files:
        if file.lower().endswith(image_extensions):
            current_folder_image_count += 1

    # Determine category based on folder name
    folder_category = None
    if 'human' in root.lower():
        folder_category = human_category
    elif 'preserved' in root.lower():
        folder_category = preserved_category
    else:
        folder_category = other_category

    # Update counts for the determined category
    folder_category['total_folders'] += 1
    if current_folder_image_count == 0:
        folder_category['0_images'] += 1
    elif current_folder_image_count == 1:
        folder_category['1_image'] += 1
    else:
        folder_category['2_plus_images'] += 1

# Function to print results for a category
def print_category_stats(name, category_data):
    print(f"\n--- Category: {name} ---")
    total = category_data['total_folders']
    if total == 0:
        print("No folders found in this category.")
        return

    print(f"Total folders: {total}")
    print(f"  Folders with 0 images: {category_data['0_images']} ({category_data['0_images'] / total:.2%})")
    print(f"  Folders with 1 image: {category_data['1_image']} ({category_data['1_image'] / total:.2%})")
    print(f"  Folders with 2+ images: {category_data['2_plus_images']} ({category_data['2_plus_images'] / total:.2%})")


# Print results for each category
print_category_stats("Contains 'human' in folder name", human_category)
print_category_stats("Contains 'preserved' in folder name", preserved_category)
print_category_stats("Does not contain 'human' or 'preserved'", other_category)
# Out:
# --- Category: Contains 'human' in folder name ---
# Total folders: 2046
#   Folders with 0 images: 1589 (77.66%)
#   Folders with 1 image: 457 (22.34%)
#   Folders with 2+ images: 0 (0.00%)
#
# --- Category: Contains 'preserved' in folder name ---
# Total folders: 1796
#   Folders with 0 images: 1386 (77.17%)
#   Folders with 1 image: 410 (22.83%)
#   Folders with 2+ images: 0 (0.00%)
#
# --- Category: Does not contain 'human' or 'preserved' ---
# Total folders: 1678
#   Folders with 0 images: 1213 (72.29%)
#   Folders with 1 image: 457 (27.23%)
#   Folders with 2+ images: 8 (0.48%)

# %% [markdown]
# ### Delete folders that do not contain exactly 1 image

# %%
import os
import shutil

dataset_flatbug_crops_dir = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops'
image_extensions = ('.png', '.jpg', '.jpeg', '.gif', '.bmp')

# List to store directories to delete
dirs_to_delete = []

for root, dirs, files in os.walk(dataset_flatbug_crops_dir):
    # We are looking for 'crops' subdirectories
    if os.path.basename(root) == 'crops':
        current_folder_image_count = 0
        for file in files:
            if file.lower().endswith(image_extensions):
                current_folder_image_count += 1

        if current_folder_image_count != 1:
            # If it doesn't contain exactly 1 image, mark its parent for deletion
            parent_dir = os.path.dirname(root)
            dirs_to_delete.append(parent_dir)

# Delete the marked directories (from most specific to most general)
# To avoid issues with deleting a parent then trying to delete its child
dirs_to_delete = sorted(list(set(dirs_to_delete)), key=len, reverse=True)

for d in dirs_to_delete:
    if os.path.exists(d):
        print(f"Deleting: {d} (does not contain exactly 1 image in its 'crops' subdirectory).")
        shutil.rmtree(d)
    else:
        print(f"Skipping deletion: {d} (already removed or not found).")

print("Cleanup complete.")
# Out:
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5761591188__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5761442991__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939029974__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939026768__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939021853__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939025593__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939016596__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5761627013__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939021674__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5938998588__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939022036__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6161201953__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939016771__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939021224__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5761598953__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Ginger_yellow_bumblebee__Bombus_pascuorum__5905988720__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Ginger_yellow_bumblebee__Bombus_pascuorum__6180087706__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761422124__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761616423__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761362895__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761737056__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761357718__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761737214__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761362678__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761340186__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761737282__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761480226__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761737136__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761458757__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761422031__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761636021__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761654791__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761357465__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5761422220__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_White_tailed_bumblebee__Bombus_hortorum__6148374420__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Ginger_yellow_bumblebee__Bombus_humilis__5939019213__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Ginger_yellow_bumblebee__Bombus_humilis__6176651722__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_White_tailed_bumblebee__Bombus_hypnorum__6115953936__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_White_tailed_bumblebee__Bombus_lucorum__4596409384__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Red_tailed_bumblebee__Bombus_pratorum__6176649141__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5935479501__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5889909083__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__3963350476__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__6399402679__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Wool_carder_bee__Anthidium_manicatum__5761381178__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4424292700__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5230377880__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5890060913__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5238169489__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5062776767__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4919570432__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4908615798__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Wool_carder_bee__Anthidium_manicatum__5761581533__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Wool_carder_bee__Anthidium_manicatum__5761328809__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4902028011__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5760802931__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Thick_legged_hoverfly__Syritta_pipiens__4894197472__supplementary_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__6131351329__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__5281939630__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__3963230473__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Wool_carder_bee__Anthidium_manicatum__5761442828__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__2641438376__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4937099465__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__2802752610__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4424420636__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4852448663__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__3333395122__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__1946197491__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Wool_carder_bee__Anthidium_manicatum__5939009323__supplementary_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4908075320__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__3963364496__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4424156773__supplementary_human (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Ginger_yellow_bumblebee__Bombus_pascuorum__3457691341__initial_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_White_tailed_bumblebee__Bombus_terrestris__1055355244__initial_preserved_2 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_White_tailed_bumblebee__Bombus_terrestris__3031182119__initial_preserved_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6195694317__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839656838__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6234828321__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839667555__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6321189420__initial_human_1 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6352697338__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6236383749__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839677178__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839653750__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839668743__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839668006__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5134369801__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839680112__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6235654922__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839666812__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5134089017__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839667552__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839671421__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839653523__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5134329687__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5139986837__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839661285__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839681512__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6320991678__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839661049__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6195332789__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839660597__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839654193__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839684171__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6185671206__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839683719__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6195983122__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839666350__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_White_tailed_bumblebee__Bombus_lucorum__6334262043__supplementary_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6235815827__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Other_moth_or_butterfly__Other_Lepidoptera__5839657068__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6334360043__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5140345779__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Small_scissor_bee__Chelostoma_campanularum__4910269350__initial_preserved (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6253308122__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6234512904__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5133583382__initial_human_0 (does not contain exactly 1 image in its 'crops' subdirectory).
# Deleting: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_flatbug_crops/cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__
'/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split'

# Define the target directories
multi_dir = os.path.join(output_base_dir, 'multi')
single_dir = os.path.join(output_base_dir, 'single')

# Create target directories if they don't exist
os.makedirs(multi_dir, exist_ok=True)
os.makedirs(single_dir, exist_ok=True)

# Get all immediate subdirectories in dataset_flatbug_crops_dir
subdirectories = [d for d in os.listdir(dataset_flatbug_crops_dir) if os.path.isdir(os.path.join(dataset_flatbug_crops_dir, d))]

# Shuffle the list of subdirectories to ensure a random split
random.shuffle(subdirectories)

# Calculate the split point for roughly equal halves
split_point = len(subdirectories) // 2

# Assign directories to 'multi' and 'single' groups
multi_group = subdirectories[:split_point]
single_group = subdirectories[split_point:]

print(f"Splitting {len(subdirectories)} folders: {len(multi_group)} for 'multi', {len(single_group)} for 'single'.")

# Move folders to the 'multi' directory
for folder_name in multi_group:
    src_path = os.path.join(dataset_flatbug_crops_dir, folder_name)
    dst_path = os.path.join(multi_dir, folder_name)
    try:
        shutil.move(src_path, dst_path)
        print(f"Moved {folder_name} to {multi_dir}")
    except Exception as e:
        print(f"Error moving {folder_name} to {multi_dir}: {e}")

# Move folders to the 'single' directory
for folder_name in single_group:
    src_path = os.path.join(dataset_flatbug_crops_dir, folder_name)
    dst_path = os.path.join(single_dir, folder_name)
    try:
        shutil.move(src_path, dst_path)
        print(f"Moved {folder_name} to {single_dir}")
    except Exception as e:
        print(f"Error moving {folder_name} to {single_dir}: {e}")

print("Dataset split complete.")
# Out:
# Splitting 1324 folders: 662 for 'multi', 662 for 'single'.
# Moved cropped_Yellow_faced_bee__Hylaeus__4413141194__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Other_fly__Diptera_except_Syrphidae__5839702128__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Flower_bee__Anthophora__1056555901__initial_preserved_1 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Leafcutter_bee__Megachile__6352344915__supplementary_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Humming_Syrphus__Syrphus__1055626698__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Mason_bee__Osmia_bicornis__1056287971__initial_preserved_2 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Honeybee_66 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Mint_moth__Pyrausta_aurata__5167459294__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Honeybee__Apis_mellifera__4974589522__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Ant__Formicidae__4922048374__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Narcissus_bulb_fly__Merodon_equestris__6334540525__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Ginger_yellow_bumblebee__Bombus_pascuorum__6195345865__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Leafcutter_bee__Megachile__1989788242__initial_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Batman_hoverfly_69 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Yellow_faced_bee__Hylaeus__2988399508__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Speckled_wood__Pararge_aegeria__6234800959__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Mason_bee__Osmia_bicornis__6195889366__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Marmalade_hoverfly__Episyrphus_balteatus__1837852848__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Honeybee_58 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5939012847__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Other_arthropods_13 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Speckled_wood__Pararge_aegeria__6234813377__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Aphid_eater_hoverfly_31 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Small_scissor_bee__Chelostoma_campanularum__5935537129__supplementary_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Globetail_hoverfly_29 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Honeybee_48 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Mason_bee__Osmia_bicornis__6273376507__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Humming_Syrphus_28 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Honeybee_19 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Globetail_hoverfly_23 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Wool_carder_bee__Anthidium_manicatum__1056040108__initial_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Drone_fly_4 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Aphid_eater_hoverfly_22 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Drone_fly__Eristalis__1837873526__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Wool_carder_bee__Anthidium_manicatum__5761368224__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Honeybee_26 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Small_scissor_bee__Chelostoma_campanularum__5761362570__supplementary_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Yellow_faced_bee__Hylaeus__5839703602__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Other_fly_17 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6253309176__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Mason_bee__Osmia_bicornis__5761570937__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Leafcutter_bee__Megachile__5177028243__supplementary_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Thick_legged_hoverfly__Syritta_pipiens__1837876366__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Speckled_wood__Pararge_aegeria__6235130408__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6195291325__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Drone_fly_53 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Speckled_wood__Pararge_aegeria__4126529977__supplementary_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Aphid_eater_hoverfly_27 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Wool_carder_bee__Anthidium_manicatum__1055450800__initial_preserved_1 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Red_tailed_bumblebee__Bombus_pratorum__6179115203__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Globetail_hoverfly_54 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Aphid_eater_hoverfly_41 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Thick_legged_hoverfly__Syritta_pipiens__1837876386__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Small_white__Pieris_rapae__6251584593__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Other_fly_27 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Common_wasp_46 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Wool_carder_bee__Anthidium_manicatum__5761363285__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Mason_bee__Osmia_bicornis__6234840884__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Wool_carder_bee__Anthidium_manicatum__5761603276__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Humming_Syrphus_38 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved Common_wasp_66 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Ginger_yellow_bumblebee__Bombus_pascuorum__5939007255__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/multi
# Moved cropped_Mint_moth__Pyrausta_aurata
to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Red_tailed_bumblebee__Bombus_pratorum__6235189044__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Beetle__Coleoptera__5839662955__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Sweat_bee__Lasioglossium__4516149047__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Wool_carder_bee__Anthidium_manicatum__5205885127__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Common_wasp_4 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_White_tailed_bumblebee__Bombus_hypnorum__6320563788__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Leafcutter_bee__Megachile__1055413733__initial_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Marmalade_hoverfly_24 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Other_fly_3 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Ginger_yellow_bumblebee__Bombus_pascuorum__5939029215__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Honeybee__Apis_mellifera__4974589321__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Narcissus_bulb_fly__Merodon_equestris__6352981066__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Flower_bee__Anthophora__6178407814__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Common_wasp__Vespula_vulgaris__1988330447__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Flower_bee__Anthophora__6178324293__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Ginger_yellow_bumblebee__Bombus_humilis__5939017895__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Aphid_eater_hoverfly_6 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Globetail_hoverfly_46 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Red_tailed_bumblebee__Bombus_sylvarum__5939005828__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Thick_legged_hoverfly__Syritta_pipiens__6320639805__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Other_fly_41 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Thick_legged_hoverfly__Syritta_pipiens__6352274438__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Narcissus_bulb_fly__Merodon_equestris__6253279479__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Small_scissor_bee__Chelostoma_campanularum__5760427026__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5134614829__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Small_scissor_bee__Chelostoma_campanularum__5890076476__supplementary_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Leafcutter_bee__Megachile__5237990489__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Honeybee_16 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Other_arthropods_8 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Red_tailed_bumblebee__Bombus_pratorum__6170979630__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Mint_moth__Pyrausta_aurata__6399689751__initial_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Sweat_bee__Lasioglossium__5838421338__supplementary_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_White_tailed_bumblebee__Bombus_hypnorum__6253159870__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6234314354__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Wool_carder_bee__Anthidium_manicatum__4893629091__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Batman_hoverfly_30 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Red_tailed_bumblebee__Bombus_lapidarius__5931877829__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Marmalade_hoverfly_12 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Drone_fly_34 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Leafcutter_bee__Megachile__2294494138__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Humming_Syrphus_27 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Small_scissor_bee__Chelostoma_campanularum__5761458573__supplementary_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Yellow_faced_bee__Hylaeus__6400495215__supplementary_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Drone_fly_31 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Yellow_faced_bee__Hylaeus__5187646384__supplementary_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Other_fly_46 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Aphid_eater_hoverfly_1 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Aphid_eater_hoverfly_59 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6235654952__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Globetail_hoverfly__Sphaerophoria__1837853302__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Small_scissor_bee__Chelostoma_campanularum__5761458958__supplementary_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Globetail_hoverfly__Sphaerophoria__1055855195__initial_preserved to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Common_wasp_6 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Mason_bee__Osmia_bicornis__5761360883__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Other_arthropods_26 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Drone_fly_33 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved Drone_fly_61 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_White_tailed_bumblebee__Bombus_vestalis__5939026583__supplementary_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Honeybee__Apis_mellifera__1057112256__initial_preserved_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Yellow_faced_bee__Hylaeus__5206637133__supplementary_human to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__6235956607__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Orange_tailed_mining_bee__Andrena_haemorrhoa__5134385826__initial_human_0 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Moved cropped_Red_tailed_bumblebee__Bombus_lapidarius__1056283013__initial_preserved_2 to /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset_split/single
# Dataset split complete.

# %% [markdown]
# ### Define categories

# %%
import os

base_gbif_images_path = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/GBIF images'

print(f"Listing immediate subfolders in: {base_gbif_images_path}\n")

if os.path.exists(base_gbif_images_path):
    all_categories = [
        d for d in os.listdir(base_gbif_images_path)
        if os.path.isdir(os.path.join(base_gbif_images_path, d))
    ]
    all_categories.sort() # Sort alphabetically for consistent numbering

    if all_categories:
        for i, category in enumerate(all_categories):
            print(f"{i}: {category}")
    else:
        print("No subfolders found in the 'GBIF images' directory.")
else:
    print(f"Error: The path '{base_gbif_images_path}' does not exist.")
# Out:
# Listing immediate subfolders in: /content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/GBIF images
#
# 0: Ant
# 1: Aphid_eater_hoverfly
# 2: Batman_hoverfly
# 3: Beetle
# 4: Common_wasp
# 5: Drone_fly
# 6: Flower_bee
# 7: Ginger_yellow_bumblebee
# 8: Globetail_hoverfly
# 9: Honeybee
# 10: Humming_Syrphus
# 11: Large_white
# 12: Leafcutter_bee
# 13: Marmalade_hoverfly
# 14: Mason_bee
# 15: Mint_moth
# 16: Narcissus_bulb_fly
# 17: Orange_tailed_mining_bee
# 18: Other_arthropods
# 19: Other_fly
# 20: Other_moth_or_butterfly
# 21: Red_tailed_bumblebee
# 22: Small_scissor_bee
# 23: Small_white
# 24: Speckled_wood
# 25: Sweat_bee
# 26: Thick_legged_hoverfly
# 27: White_tailed_bumblebee
# 28: Wool_carder_bee
# 29: Yellow_faced_bee

# %% [markdown]
# ### Superimpose segmented crops on background image to create composite images and generate YOLO annotations

# %%
from PIL import Image
import os
import random
import re

# Assuming all_categories and category_to_id are defined globally from previous cells.
# They are needed for extract_category_from_filename.

# Define helper function (copied for self-containment)
def clean_filename_for_output(filename):
    cleaned = re.sub(r'_CROPNUMBER_\d+_UUID_[0-9a-fA-F-]+', '', filename)
    cleaned = re.sub(r'_CROPNUMBER_\d+$', '', cleaned)
    cleaned = re.sub(r'_UUID_[0-9a-fA-F-]+$', '', cleaned)
    cleaned = re.sub(r'^(synthetic_)?crop_cropped_|^crop_|^cropped_', '', cleaned)
    return cleaned

# Define helper function (copied for self-containment)
def extract_category_from_filename(filename):
    # Remove the 'synthetic_' prefix
    name_without_prefix = filename.replace('synthetic_', '', 1)

    # Remove the '.txt' extension
    name_without_ext = os.path.splitext(name_without_prefix)[0]

    # Check if any category name from all_categories is present in the filename
    # Sort by length in descending order to ensure longer names are matched first
    sorted_categories = sorted(all_categories, key=len, reverse=True)
    for category in sorted_categories:
        if category in name_without_ext:
            return category

    # print(f"Warning: Could not reliably extract category from {filename}. Manual inspection might be needed.")
    return None


# SWAPPED: Now generating single images from the original 'multi' dataset
source_insect_dir = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/dataset'
background_image_path = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/frame.jpg'

# New output directories to distinguish from previous runs
output_images_dir_single_from_multi = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/synthetic_dataset/images'
output_labels_dir_single_from_multi = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/synthetic_dataset/labels'

# Create output directories if they don't exist
os.makedirs(output_images_dir, exist_ok=True)
os.makedirs(output_labels_dir, exist_ok=True)

# Load the background image
try:
    background = Image.open(background_image_path).convert("RGB")
    bg_width, bg_height = background.size
except FileNotFoundError:
    print(f"Error: Background image not found at {background_image_path}")
    exit()
except Exception as e:
    print(f"Error loading background image: {e}")
    exit()

# Get all subdirectories (which are the insect folders) in the source_insect_dir
insect_folders = [d for d in os.listdir(source_insect_dir) if os.path.isdir(os.path.join(source_insect_dir, d))]

if not insect_folders:
    print(f"No insect folders found in {source_insect_dir}")
else:
    print(f"Found {len(insect_folders)} insect folders to process.")

for folder_name in insect_folders:
    folder_path = os.path.join(source_insect_dir, folder_name)
    # The actual image is expected inside a 'crops' subfolder within each insect folder
    crops_folder_path = os.path.join(folder_path, 'crops')

    png_files_in_crop = [f for f in os.listdir(crops_folder_path) if f.lower().endswith('.png')]

    if not png_files_in_crop:
        print(f"No PNG files found in {crops_folder_path}. Skipping.")
        continue

    # Assuming there's exactly one PNG per crops folder after the previous cleanup
    png_filename = png_files_in_crop[0]
    png_filepath = os.path.join(crops_folder_path, png_filename)

    try:
        insect_img = Image.open(png_filepath).convert("RGBA")

        # Determine target size: 5-15% of the *smaller* background dimension
        min_bg_dim = min(bg_width, bg_height)
        scale_factor = random.uniform(0.05, 0.15)
        target_side_length = int(min_bg_dim * scale_factor)

        # Resize insect image while maintaining aspect ratio
        original_insect_width, original_insect_height = insect_img.size
        if original_insect_width == 0 or original_insect_height == 0:
            print(f"Warning: Insect image {png_filename} has zero dimension. Skipping.")
            continue

        if original_insect_width > original_insect_height:
            new_insect_width = target_side_length
            new_insect_height = int(original_insect_height * (target_side_length / original_insect_width))
        else:
            new_insect_height = target_side_length
            new_insect_width = int(original_insect_width * (target_side_length / original_insect_height))

        # Ensure new dimensions are at least 1x1
        new_insect_width = max(1, new_insect_width)
        new_insect_height = max(1, new_insect_height)

        resized_insect = insect_img.resize((new_insect_width, new_insect_height), Image.LANCZOS)

        # Calculate random position to place the insect fully within the background
        max_x = bg_width - new_insect_width
        max_y = bg_height - new_insect_height

        if max_x < 0 or max_y < 0:
            print(f"Warning: Insect image {png_filename} is larger than background even after scaling ({new_insect_width}x{new_insect_height} vs {bg_width}x{bg_height}). Skipping.")
            continue

        paste_x = random.randint(0, max_x)
        paste_y = random.randint(0, max_y)

        # Create a copy of the background to paste on for each insect
        combined_img = background.copy()

        # Paste the resized insect image onto the background using its alpha channel as a mask
        combined_img.paste(resized_insect, (paste_x, paste_y), resized_insect)

        # Clean filename for output
        cleaned_filename = clean_filename_for_output(os.path.splitext(png_filename)[0])

        # Save the combined image
        output_img_filename = f"synthetic_single_from_multi_{cleaned_filename}.jpg" # Changed prefix
        output_img_filepath = os.path.join(output_images_dir_single_from_multi, output_img_filename)
        combined_img.save(output_img_filepath)

        # Generate YOLO annotation file
        # Calculate normalized bounding box coordinates
        bbox_x_center = (paste_x + new_insect_width / 2) / bg_width
        bbox_y_center = (paste_y + new_insect_height / 2) / bg_height
        bbox_width = new_insect_width / bg_width
        bbox_height = new_insect_height / bg_height

        # Extract category and get ID using the helper function
        category_name = extract_category_from_filename(os.path.basename(png_filepath))
        category_id = category_to_id.get(category_name, 0) # Default to 0 if not found

        yolo_annotation = f"{category_id} {bbox_x_center} {bbox_y_center} {bbox_width} {bbox_height}"
        output_label_filename = f"synthetic_single_from_multi_{cleaned_filename}.txt" # Changed prefix
        output_label_filepath = os.path.join(output_labels_dir_single_from_multi, output_label_filename)

        with open(output_label_filepath, 'w') as f:
            f.write(yolo_annotation)

        print(f"Processed {png_filename}: Saved image to {output_images_dir_single_from_multi} and annotation to {output_labels_dir_single_from_multi}")

    except Exception as e:
        print(f"Error processing {png_filename}: {e}")

print("Finished generating synthetic dataset with YOLO annotations.")

# %% [markdown]
# ### Inspect images for sanity check

# %%
from PIL import Image, ImageDraw
import os
import random
import matplotlib.pyplot as plt

# Assuming category_to_id is defined globally from previous cells.
# Reverse mapping from ID to category name for display
id_to_category = {v: k for k, v in category_to_id.items()}

def plot_image_with_bboxes(image_path, label_path, dataset_type):
    try:
        img = Image.open(image_path).convert("RGB")
        draw = ImageDraw.Draw(img)
        img_width, img_height = img.size

        with open(label_path, 'r') as f:
            for line in f:
                parts = line.strip().split(' ')
                if len(parts) == 5:
                    class_id = int(parts[0])
                    x_center, y_center, bbox_width, bbox_height = map(float, parts[1:])

                    # Convert normalized YOLO coordinates to pixel coordinates
                    x_min = int((x_center - bbox_width / 2) * img_width)
                    y_min = int((y_center - bbox_height / 2) * img_height)
                    x_max = int((x_center + bbox_width / 2) * img_width)
                    y_max = int((y_center + bbox_height / 2) * img_height)

                    # Draw bounding box (red rectangle)
                    draw.rectangle([x_min, y_min, x_max, y_max], outline="red", width=3)

                    # Get category name for display
                    category_name = id_to_category.get(class_id, f"Unknown_{class_id}")
                    draw.text((x_min + 5, y_min + 5), category_name, fill="red")

        plt.imshow(img)
        plt.title(f"{dataset_type}: {os.path.basename(image_path)}")
        plt.axis('off')
        plt.show()

    except FileNotFoundError:
        print(f"Error: File not found - {image_path} or {label_path}")
    except Exception as e:
        print(f"Error processing {image_path}: {e}")


# --- Display 3 'single' insect synthetic frames (from original multi source) ---
print("Displaying 3 single insect synthetic frames (from original multi source):")
output_images_dir_single_from_multi = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/synthetic_dataset/images_single_from_multi'
output_labels_dir_single_from_multi = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/synthetic_dataset/labels_single_from_multi'

single_from_multi_images = [f for f in os.listdir(output_images_dir_single_from_multi) if f.endswith('.jpg')]
random.shuffle(single_from_multi_images)

for i in range(min(3, len(single_from_multi_images))):
    img_filename = single_from_multi_images[i]
    label_filename = img_filename.replace('.jpg', '.txt')
    image_path = os.path.join(output_images_dir_single_from_multi, img_filename)
    label_path = os.path.join(output_labels_dir_single_from_multi, label_filename)
    plot_image_with_bboxes(image_path, label_path, 'Single (from Multi)')


# --- Display 2 'multi' insect synthetic frames (from original single source) ---
print("\nDisplaying 2 multi insect synthetic frames (from original single source):")
output_images_dir_multi_from_single = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/synthetic_dataset/images_multi_from_single'
output_labels_dir_multi_from_single = '/content/drive/MyDrive/Colab Notebooks/Pollinator Camera Project/synthetic_dataset/labels_multi_from_single'

multi_from_single_images = [f for f in os.listdir(output_images_dir_multi_from_single) if f.endswith('.jpg')]
random.shuffle(multi_from_single_images)

for i in range(min(2, len(multi_from_single_images))):
    img_filename = multi_from_single_images[i]
    label_filename = img_filename.replace('.jpg', '.txt')
    image_path = os.path.join(output_images_dir_multi_from_single, img_filename)
    label_path = os.path.join(output_labels_dir_multi_from_single, label_filename)
    plot_image_with_bboxes(image_path, label_path, 'Multi (from Single)')
# Out:
# Displaying 3 single insect synthetic frames (from original multi source):
# Displaying 2 multi insect synthetic frames (from original single source):
